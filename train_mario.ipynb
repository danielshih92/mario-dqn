# %%
# !nvidia-smi
# Out:
# Mon Dec 22 12:01:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
# !git clone https://github.com/danielshih92/mario-dqn.git
# %cd mario-dqn
# !pip install -r requirements.txt
# Out:
# Cloning into 'mario-dqn'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 4), reused 28 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 27.33 KiB | 13.67 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/mario-dqn
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.5 MB/s eta 0:00:00
# ...
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp312-cp312-linux_x86_64.whl size=535722 sha256=56573e980e50e2e8f877b45f75e2febc55c29af2afe6a30f728fc9fbe0edefa1
#   Stored in directory: /root/.cache/pip/wheels/1f/a7/fa/9b0357f258d2e68bdc71df972e02418bceb02355ac1f365c59
# Successfully built nes-py
# ...

# %%
# !python run.py
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# Traceback (most recent call last):
#   File "/content/mario-dqn/run.py", line 258, in <module>
#     main()
#   File "/content/mario-dqn/run.py", line 151, in main
#     env = make_env()
#           ^^^^^^^^^^
#   File "/content/mario-dqn/run.py", line 60, in make_env
#     env = gym_super_mario_bros.make(ENV_ID)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ### push

# %%
# # 0) 進到你的 repo 目錄（請確認路徑正確）
# cd /d/mario
# pwd

# # 1) 確認目前分支（應該是 main）
# git branch

# # 2) 先看有哪些檔案被改動
# git status

# # 3) 把你改動的檔案加入版本控制（推薦一次全加）
# git add -A

# # 4) 再確認一次（避免把不該上的東西加進去）
# git status

# # 5) Commit（訊息你可自行改）
# git commit -m "fix reward functions and training script"

# # 6) 拉遠端最新（避免 non-fast-forward）
# git pull --rebase origin main

# # 7) Push 到 GitHub
# git push origin main

'''
git status
git add -A
git commit -m "fix requirements.txt"
git pull --rebase origin main
git push origin main
'''
